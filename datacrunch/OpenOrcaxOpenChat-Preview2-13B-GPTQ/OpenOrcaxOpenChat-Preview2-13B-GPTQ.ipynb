# %%
# !pip install --upgrade git+https://github.com/huggingface/transformers
# !pip install bitsandbytes
# !pip install accelerate
# !pip install auto-gptq
# !pip install optimum
# !pip install contractions
# Out:
# Requirement already satisfied: bitsandbytes in ./miniconda3/envs/fastai/lib/python3.10/site-packages (0.41.1)
# Requirement already satisfied: accelerate in ./miniconda3/envs/fastai/lib/python3.10/site-packages (0.24.1)
# Requirement already satisfied: packaging>=20.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: pyyaml in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from accelerate) (6.0)
# Requirement already satisfied: numpy>=1.17 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from accelerate) (1.22.4)
# Requirement already satisfied: torch>=1.10.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from accelerate) (2.1.0)
# Requirement already satisfied: psutil in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from accelerate) (5.9.1)
# Requirement already satisfied: huggingface-hub in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from accelerate) (0.17.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.0.9)
# Requirement already satisfied: triton==2.1.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: networkx in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: jinja2 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: filelock in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.8.0)
# Requirement already satisfied: typing-extensions in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (4.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: sympy in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: fsspec in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2023.10.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.18.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.3.52)
# Requirement already satisfied: tqdm>=4.42.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from huggingface-hub->accelerate) (4.64.0)
# Requirement already satisfied: requests in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.3)
# Requirement already satisfied: mpmath>=0.19 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: auto-gptq in ./miniconda3/envs/fastai/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: sentencepiece in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from auto-gptq) (0.1.97)
# Requirement already satisfied: torch>=1.13.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from auto-gptq) (2.1.0)
# Requirement already satisfied: datasets in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from auto-gptq) (2.4.0)
# Requirement already satisfied: accelerate>=0.22.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from auto-gptq) (0.24.1)
# Requirement already satisfied: transformers>=4.31.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from auto-gptq) (4.36.0.dev0)
# Requirement already satisfied: gekko in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from auto-gptq) (1.0.6)
# Requirement already satisfied: peft>=0.5.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from auto-gptq) (0.6.0)
# Requirement already satisfied: numpy in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from auto-gptq) (1.22.4)
# Requirement already satisfied: rouge in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from auto-gptq) (1.0.1)
# Requirement already satisfied: tqdm in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from auto-gptq) (4.64.0)
# Requirement already satisfied: safetensors in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from auto-gptq) (0.4.0)
# Requirement already satisfied: packaging>=20.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from accelerate>=0.22.0->auto-gptq) (21.3)
# Requirement already satisfied: huggingface-hub in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from accelerate>=0.22.0->auto-gptq) (0.17.3)
# Requirement already satisfied: pyyaml in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from accelerate>=0.22.0->auto-gptq) (6.0)
# Requirement already satisfied: psutil in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from accelerate>=0.22.0->auto-gptq) (5.9.1)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (8.9.2.26)
# Requirement already satisfied: sympy in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (1.12)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (12.1.3.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (2.18.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (11.0.2.54)
# Requirement already satisfied: filelock in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (3.8.0)
# Requirement already satisfied: networkx in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (3.2.1)
# Requirement already satisfied: fsspec in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: typing-extensions in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (4.3.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (11.4.5.107)
# Requirement already satisfied: triton==2.1.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (2.1.0)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: jinja2 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (3.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (12.1.0.106)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->auto-gptq) (12.3.52)
# Requirement already satisfied: regex!=2019.12.17 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers>=4.31.0->auto-gptq) (2022.4.24)
# Requirement already satisfied: requests in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers>=4.31.0->auto-gptq) (2.28.1)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers>=4.31.0->auto-gptq) (0.14.1)
# Requirement already satisfied: dill<0.3.6 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->auto-gptq) (0.3.5.1)
# Requirement already satisfied: pandas in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->auto-gptq) (1.4.3)
# Requirement already satisfied: responses<0.19 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->auto-gptq) (0.18.0)
# Requirement already satisfied: multiprocess in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->auto-gptq) (0.70.12.2)
# Requirement already satisfied: aiohttp in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->auto-gptq) (3.8.1)
# Requirement already satisfied: pyarrow>=6.0.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->auto-gptq) (8.0.0)
# Requirement already satisfied: xxhash in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->auto-gptq) (0.0.0)
# Requirement already satisfied: six in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (6.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (2.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (4.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from packaging>=20.0->accelerate>=0.22.0->auto-gptq) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->transformers>=4.31.0->auto-gptq) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->transformers>=4.31.0->auto-gptq) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->transformers>=4.31.0->auto-gptq) (1.26.11)
# Requirement already satisfied: MarkupSafe>=2.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from pandas->datasets->auto-gptq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from pandas->datasets->auto-gptq) (2022.2.1)
# Requirement already satisfied: mpmath>=0.19 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from sympy->torch>=1.13.0->auto-gptq) (1.3.0)
# Collecting optimum
#   Downloading optimum-1.14.0.tar.gz (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 24.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: sympy in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from optimum) (1.12)
# Requirement already satisfied: packaging in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from optimum) (21.3)
# Requirement already satisfied: torch>=1.9 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from optimum) (2.1.0)
# Requirement already satisfied: datasets in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from optimum) (2.4.0)
# Requirement already satisfied: huggingface-hub>=0.8.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from optimum) (0.17.3)
# Requirement already satisfied: numpy in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from optimum) (1.22.4)
# Requirement already satisfied: transformers[sentencepiece]>=4.26.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from optimum) (4.36.0.dev0)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from huggingface-hub>=0.8.0->optimum) (3.8.0)
# Requirement already satisfied: fsspec in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from huggingface-hub>=0.8.0->optimum) (2023.10.0)
# Requirement already satisfied: tqdm>=4.42.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from huggingface-hub>=0.8.0->optimum) (4.64.0)
# Requirement already satisfied: pyyaml>=5.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from huggingface-hub>=0.8.0->optimum) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from huggingface-hub>=0.8.0->optimum) (4.3.0)
# Requirement already satisfied: requests in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from huggingface-hub>=0.8.0->optimum) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from packaging->optimum) (3.0.9)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (8.9.2.26)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (12.1.0.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (10.3.2.106)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (12.1.3.1)
# Requirement already satisfied: networkx in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (3.2.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (11.0.2.54)
# Requirement already satisfied: triton==2.1.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (2.1.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (2.18.1)
# Requirement already satisfied: jinja2 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (3.1.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.9->optimum) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9->optimum) (12.3.52)
# Requirement already satisfied: regex!=2019.12.17 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers[sentencepiece]>=4.26.0->optimum) (2022.4.24)
# Requirement already satisfied: safetensors>=0.3.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.4.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.14.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.1.97)
# Collecting protobuf
#   Downloading protobuf-4.25.0-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.4/294.4 kB 31.6 MB/s eta 0:00:00
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: responses<0.19 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->optimum) (0.18.0)
# Requirement already satisfied: multiprocess in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->optimum) (0.70.12.2)
# Requirement already satisfied: pandas in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->optimum) (1.4.3)
# Requirement already satisfied: aiohttp in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->optimum) (3.8.1)
# Requirement already satisfied: xxhash in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->optimum) (0.0.0)
# Requirement already satisfied: pyarrow>=6.0.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->optimum) (8.0.0)
# Requirement already satisfied: dill<0.3.6 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from datasets->optimum) (0.3.5.1)
# Requirement already satisfied: mpmath>=0.19 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (2.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (1.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from jinja2->torch>=1.9->optimum) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from pandas->datasets->optimum) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from pandas->datasets->optimum) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./miniconda3/envs/fastai/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->datasets->optimum) (1.16.0)
# Building wheels for collected packages: optimum
#   Building wheel for optimum (pyproject.toml) ... done
#   Created wheel for optimum: filename=optimum-1.14.0-py3-none-any.whl size=398917 sha256=1b930346fcc1ce6e21eee4d722caf7735ef3d22ca32289d22d00dd3b0d245e58
#   Stored in directory: /home/user/.cache/pip/wheels/b5/d3/b9/9667517bdcd7d15c43e804c8c0f88b006a85c7560f58e97ff5
# Successfully built optimum
# Installing collected packages: protobuf, humanfriendly, coloredlogs, optimum
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 optimum-1.14.0 protobuf-4.25.0

# %%
import torch
import transformers
from torch import cuda, bfloat16

torch.cuda.set_device(0)

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'
device_name = torch.cuda.get_device_name()
print(f"Using device: {device} ({device_name})")
# Out:
# Using device: cuda:0 (NVIDIA RTX A6000)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import torch.fx
def initiateModelAndTokenizer():

    model_name_or_path = "TheBloke/Llama-2-7B-Chat-GPTQ"
    model = AutoModelForCausalLM.from_pretrained(model_name_or_path,
                                                device_map = "auto",
                                                trust_remote_code = True,
                                                revision = "main")

    tokenizer = AutoTokenizer.from_pretrained(model_name_or_path, use_fast = True)

    return model, tokenizer

# Inicjuje model i tokenizer
model, tokenizer = initiateModelAndTokenizer()
# Out:
# Downloading model.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]

# %%
import pandas as pd
import numpy as np
import contractions
import re
import json
import os
from json import JSONDecodeError

# %%
# !ls
# Out:
#  batch1.ipynb   fastbook     requirements.txt	    run.sh
#  env.yml        miniconda3  'reviews (1).parquet'

# %%
# KONFIGURACJA

# Ścieżka do katalogu ze skryptem - punkt odniesienia do tworzenia pozostałych katalogów
#script_dir = "/content/drive/MyDrive/Colab Notebooks/revbox_local/"
script_dir = ""

# Ścieżka do pliku ze wszystkimi recenzjami
reviews_path = "reviews.parquet"

# Liczba recenzji, po których zapisuje aktualne wyniki
save_checkpoint = 50

# %%
# DEFINICJE FUNKCJI

def extractFeatures(review):

    user_prompt = f"""
    Extract most important product features from provided review.
    List all extracted features.
    Write the response as a Python list of dictionaries with three key-value pairs each.
    First key should be called "category" and value should be feature category.
    Second key should be called "quote" and value should be quote from review.
    Third key should be called "sentiment" and value should be "positive", "negative" or "neutral" depending on sentiment of the quoted text.
    Do not name the dictionary.
    Do not make up features if you will not find anything in review.
    The list may have one or more dictionaries.
    The list can be empty if there are no features mentioned in provided review.

    This is the review:

    {review}
    """

    prompt = f"""
    [INST] <<SYS>>
    You are an objective assistant and your task is to help with extracting important information from product reviews.
    You only analyze information stated in provided text.
    You focus only on product features.
    If you cannot extract any product features then do not make up features which were not mentioned in provided text.
    <</SYS>>
    {user_prompt}[/INST]
    """

    input_ids = tokenizer(prompt, return_tensors = "pt").input_ids.cuda()
    output = model.generate(inputs = input_ids,
                            temperature = 0.01,
                            do_sample = True,
                            top_p = 0.01,
                            top_k = 10,
                            max_new_tokens = 512)

    result = tokenizer.decode(output[0])
    #print(result)

    result_list = convertResultToListOfDictionaries(result)

    return result_list



def countReviewsPerProduct():

    products = reviews.groupby(["product_name"]).agg({"product_name": np.size})
    products.columns = ["number_of_reviews"]
    products = products.reset_index()
    products = products.sort_values(by = "number_of_reviews")
    products = products.reset_index(drop = True)

    return products



def cleanText(text):

    # Zamienia powielone kropki na pojedynczą kropkę i spację
    text = re.sub("\.+", ". ", text)

    # Usuwa powielone spacje
    text = re.sub(" +", " ", text)

    # Usuwa white spaces z początku i końca
    text = text.strip()

    # Rozwija skróty, np. you're = you are
    text = contractions.fix(text)

    # Zamienia cudzysłów na apostrof
    text = text.replace("\"", "'")

    return text



def convertResultToListOfDictionaries(result):

    # Wyciąga z odpowiedzi fragment z kodem i konwertuje go do listy słowników
    result = result.split("[/INST]")[1]
    result = result.split("[")[1]
    result = result.split("]")[0]
    result = "[" + result.strip() + "]"
    result = re.sub("},]", "}]", result)

    try:
        result_list = json.loads(result)
    except JSONDecodeError:
        with open(f"{script_dir}errors/{filename}.txt", "a") as f:
                    f.write(f"review_index: {r}\nJSONDecodeError:\n{result}\n\n\n")
        return result

    return result_list

# %%
# Tworzy katalog z informacjami o błędach
if not os.path.exists(script_dir + "errors"):
    os.makedirs(script_dir + "errors")

# Tworzy katalog z wynikami
if not os.path.exists(script_dir + "results"):
    os.makedirs(script_dir + "results")

# Wczytuje wszystkie recenzje z pliku
reviews = pd.read_parquet(reviews_path)

# Sprawdza czy istnieje plik z informacją o tym ile recenzji zostało już przetworzonych,
# jeśli nie ma, to tworzy go od nowa
if not os.path.exists(script_dir + "products.csv"):
    # Grupuje produkty według liczby recenzji
    products = countReviewsPerProduct()
    products["processed_reviews"] = 0
    products["next_index"] = 0
    products.to_csv(script_dir + "products.csv", index = False)
else:
    products = pd.read_csv(script_dir + "products.csv")

# %%
# Dla każdego produktu
counter = 0
import datetime
for p in range(len(products)):

    # Sprawdza czy wszystkie recenzje danego produktu zostały już przetworzone,
    # niektóre recenzje mogły być pominięte ze względu na błędy,
    # dlatego sprawdza jaki powinien być indeks następnej recenzji (początek od 0)
    if products.loc[p, "next_index"] < products.loc[p, "number_of_reviews"]:

        product = products.loc[p, "product_name"]

        # Wydziela wszystkie recenzje wybranego produktu
        product_reviews = reviews.loc[reviews["product_name"] == product, ["review_title", "review_content"]].copy()
        product_reviews = product_reviews.reset_index(drop = True)

        # Czyści teksty recenzji
        product_reviews["review_content"] = product_reviews["review_content"].apply(cleanText)

        # Sprawdza czy istnieje już plik z wyekstraktowanymi cechami danego produktu
        filename = re.sub(" ", "_", product)
        if not os.path.exists(script_dir + "results/" + filename + ".csv"):
            # Tworzy dataframe, do którego będą dopisywane kategorie cech produktu oraz cytaty z recenzji
            features = pd.DataFrame()
        else:
            features = pd.read_csv(script_dir + "results/" + filename + ".csv")

        start_index = products.loc[p, "next_index"]
        processed_reviews = products.loc[p, "processed_reviews"]

        # Dla każdej recenzji
        for r in range(start_index, len(product_reviews)):
            review = product_reviews.loc[r, "review_content"]
            now = datetime.datetime.now()
            print(counter, now,  review)
            counter = counter +1    
            # Stosuje algorytm do ekstrakcji cech i dopisuje do zbiorczej tabeli
            try:
                features_list = extractFeatures(review)
                # Jeśli zwróciło string zamiast listy, tzn. że był problem z konwersją
                # i przechodzi do kolejnej recenzji (informacje o błędzie są zapisywane)
                if type(features_list) == str:
                    continue
                features_tmp = pd.DataFrame(features_list)
                features = pd.concat([features, features_tmp])
            except Exception as e:
                error = type(e).__name__ + ":\n" + str(e)
                with open(f"{script_dir}errors/{filename}.txt", "a") as f:
                    f.write(f"review_index: {r}\n{error}\n\n\n")
                continue

            # Zapisuje aktualne wyniki jeśli osiągnęło ustalony checkpoint
            processed_reviews = processed_reviews + 1
            if processed_reviews % save_checkpoint == 0:
                features.to_csv(script_dir + "results/" + filename + ".csv", index = False)
                products.loc[p, "processed_reviews"] = processed_reviews
                products.loc[p, "next_index"] = r + 1
                products.to_csv(script_dir + "products.csv", index = False)

        features = features.reset_index(drop = True)
        features["category"] = features["category"].str.lower()
        features["sentiment"] = features["sentiment"].str.lower()

        # Zapisuje całość wyników dla danego produktu
        features.to_csv(script_dir + "results/" + filename + ".csv", index = False)
        products.loc[p, "processed_reviews"] = processed_reviews
        products.loc[p, "next_index"] = len(product_reviews)
        products.to_csv(script_dir + "products.csv", index = False)
# Out:
# 0 2023-11-07 14:38:53.250400 I bought this phone as a replacement to Samsung. Since I am using it is been a night mare to keep it connected to cellular service. It keeps losing cellular connection with an E symbol. I need to reboot this phone every time to keep it connected to LTE service. I can not return this phone now or Helpdesk is able to help me to resolve this issue.
# 1 2023-11-07 14:38:57.664676 after the phone updates it informs you that it is now compatible with verizons network. Had to return. It worked great before the update though.
# 2 2023-11-07 14:39:03.779616 GREAT PHONE! Does everything & anything YOU want to in a cell phone. great value & a great batttery-lasts all day & night. better value than Iphone 13. and much. much. cheaper!!!
# 3 2023-11-07 14:39:14.700524 It is Great! Holds a charge for a couple of days. It is quick. My son's really likes it. Great price too.
# 4 2023-11-07 14:39:20.255604 I am enjoying my phone , it is working smooth and it is fast when I load the new apps it is the fastest cell I ever have.
# 5 2023-11-07 14:39:22.820759 I liked the size of the phone. So far it is working very good, fast and easy to navigate the phone.
# 6 2023-11-07 14:39:28.052614 This is a great phone for that price and many great features.
# 7 2023-11-07 14:39:32.948238 Very responsive, camera work good for the most part.
# 8 2023-11-07 14:39:39.425874 great phone for the conscious user. 7h SOT with very intensive use during the first use.
# 9 2023-11-07 14:39:44.932677 The product turns on and the touch screen goes, let us see if I can change the screen
# 10 2023-11-07 14:39:48.425295 Super fast, everything corresponds to the description ;)
# 11 2023-11-07 14:39:54.915974 wow , this is a vary nice cell phone at a nice price. It feels great to handle, feels comfy in your hand, not too bulky or heavy, though heaver than my last rugged phone . Very fast opening apps , easy to use easy to see, colours on the screen are bright and clear, i like it very much an can recommend it.
# 12 2023-11-07 14:40:10.364003 The format is pleasant in the hand. The screen is readable in direct sunlight, no problem on that side. Autonomy level, again Blackview keeps its promises, and I suppose the same goes for robustness. The problem comes from the software processing of the photo announced as a 'miracle' thanks to ArcSoft, a US company which provides software solutions in the field of the image which is supposed to be on board this smartphone. Despite the description of this BV5200 Pro, the reality is quite different. The photos are almost unusable as they are pitted and dull. The HDR mode is inoperative and I switch to the night mode which delivers a porridge. I already had a Blackview BV5100 in the past, the ancestor of this BV5200 Pro which did much better. In short, Blackview is regressing but at the same time, what can we expect from a rugged smartphone at this price? Certainly no miracles, I confirm it to you. 1 star is still too much. Thank you for reading this review, hope it helps you. Less
# 13 2023-11-07 14:40:25.864006 I chose this smartphone for its robustness and its autonomy. Its 5180 mAh battery allows you to recharge it every two or three days. It is also handy for using it as a GPS on long journeys without having to plug it into the cigarette lighter. Its design is very beautiful for an unbreakable phone: the colored band, a photo lens in the shape of a drop of water, the finish of the keys, the waterproof covers as well as the protective she will. It is also thinner than others. unbreakable models. The handling is intuitive and pleasant. Facial recognition is a plus compared to other models of the brand. The quality of the photos is more than adequate for an unbreakable phone, especially with its many possible settings (night mode, beauty mode (adjustable), panoramic, etc. ). Note however that there is no jack for any headphones, but I use wireless headphones for my part. Less
# 14 2023-11-07 14:40:41.383300 Too expensive, compared to the previous model, the a60. With the same performance, felt by the user. Positive: battery charging time Negative: screen saver time not modifiable. No fingerprint sensor
# 15 2023-11-07 14:40:47.834443 I was looking for an Android phone that could replace my old phone that just left me. And I came across this brand for its - It is powerful, has a fingerprint sensor, facial recognition, several cameras for different zooms. - The configuration is very fast and the photo management efficient. -In terms of autonomy, we have a huge battery that lasts well. -a very powerful speaker that really impressed me for a phone like that. -it is fluid with a good processor accompanied by 4 GB of ram + 128 GB of rom. I recommend it because it is perfect for Intense use At this price it is top
# 16 2023-11-07 14:40:55.223873 Smartphone perfect for a teenager who breaks everything! In addition, its black and green look gives it the appearance of a gamer's accessory and not that of a smartphone of a public construction site employee.
# 17 2023-11-07 14:41:00.349205 Phone that works well in terms of applications, but in terms of calls it is a disaster, my interlocutors do not hear what I am saying. Phone only for apps and sms.
# 18 2023-11-07 14:41:04.290414 easy to use phone, fast process. The quality of the photos is great. The memory large enough to be able to save files. The strap behind the phone is practical, it allows you to hold the phone well.
# 19 2023-11-07 14:41:07.184275 Quick start. Exactly meets my expectations.
# 20 2023-11-07 14:41:10.718424 Very functional phone with the small torch, the fingerprint reader on the edge which is well placed, the processor is sufficient for the Web and games, APN more than adequate with a wide angle, the 128 gigabytes of storage allows you to do without a memory card, large capacity, The sound remains correct with no parasitic noise, gives an impression of robustness hence its weight and dimensions more marked than a classic 5. 5 inch.
# 21 2023-11-07 14:41:26.053191 great product quality price
# 22 2023-11-07 14:41:30.942464 Have not had time to use it yet but as ordered
# 23 2023-11-07 14:41:33.269761 Enough for what I do
# 24 2023-11-07 14:41:38.630599 I like the slightly heavier mobiles, like Ulefone. Ordinary mobile phones too often feel like plastic toys in the hand. The battery lasts for several days even with a lot of use. Stylish design and fun to play with. An affordable phone, which also charges quickly. An experience for both the hand and the eye. The headphones work, but if there will be an updated version of this model, the headphones must have a better connection to the phone so that it does not become choppy when the phone is in the pocket and the earphones are in the ears. A case should also be included in the box for convenience. But Ulefone has made a cool first model of a mobile with built-in headphones. If you can continue and take it to the next level without losing the nice design, it can be great without paying exorbitant prices. Less
# 25 2023-11-07 14:41:54.068099 A really good cell phone for a heavy-duty man. An excellent addition is the Bluetooth headphones, which are always charged and included because they are integrated directly into the cell phone frame. The frame is really strong and will certainly withstand even the most demanding conditions. You can use it to shoot underwater if needed :).
# 26 2023-11-07 14:41:58.847160 Large battery, lasts almost a whole week without needing to be charged. Good as a work phone. The only 'flaw' is that the supplied earplugs have a rather harsh sound.
# 27 2023-11-07 14:42:02.610243 Good phone, a little big, a little heavy, but not bad with its integrated headphones. Very good listening, I recommend it! The screen is a bit small for games, too bad😏
# 28 2023-11-07 14:42:05.743850 Very satisfied, a very good phone, I recommend a serious company, thank you
# 29 2023-11-07 14:42:11.579069 You cannot get everything for this money. So the camera side is bad in this model. Otherwise, it is a good game for the price.
# 30 2023-11-07 14:42:15.009118 I came across a factory defect, the touch went crazy after charging the phone when the phone was warm
# 31 2023-11-07 14:42:20.534766 Superb Works perfectly, brilliant solution with handsets in the phone
# 32 2023-11-07 14:42:25.637757 After a few weeks, no complaints. It works flawlessly.
# 33 2023-11-07 14:42:32.259840 The phone is solid and really nice looking, great to use
# 34 2023-11-07 14:42:37.966315 Very very good workmanship and quality too
# 35 2023-11-07 14:42:41.386639 Good phone but a bit heavy otherwise very good
# 36 2023-11-07 14:42:46.920286 Good durable mobile, a little bigger than expected.
# 37 2023-11-07 14:42:54.098444 after a week the phone stopped working and for that week I had to charge it every day I do not recommend it
# 38 2023-11-07 14:42:58.389274 Great phone in tough conditions.
# 39 2023-11-07 14:43:04.033969 Here are my experiences after a good month of use. The battery really lasts quite a long time, about 3-4 days of heavy use, almost up to a week if you do not drool all the time. The screen is really clear and you can see very well in sunny weather, even in direct sunlight. It came with a 66W charger, but the old charging plate 10W works, about 30% to a full battery at night during sleep (7h). So I have not used the charger that came with it, yet. The cameras work decently in poor lighting, but the flash/flashlight is really bright and improves the description of dark objects considerably. Listening to music is possible, the built-in speaker is good for hearing, maybe too loud at times. When working with Raksa, so I bought this phone because of its durability and water resistance, the phone has already 'swimmed' and dropped a few times and there is no visible damage. The 'frame' of the phone is rubber and takes shocks perfectly. In this model, the protection of the cameras was taken into account, there is a small 'rubber frame' around the cameras to protect the camera lenses from impacts. The old 5100 Nokia's shells were probably made of the same rubber ;) The price was 'expensive', but if the handset lasts for a good two years again, it is not a bad deal. I am very satisfied, already my third Ulefone, so I am not changing the brand of 'durable' phones. Less
# 40 2023-11-07 14:43:16.712593 The product corresponds to my wishes and the statements on the website. The case is well stiffened, the battery is big enough. If you disable location, 5G connectivity (when they are not needed) and use the Data Saver correctly, the battery lasts over 10 days with normal use. It allows a granular customization that obviously requires some time, during the initial setup of the phone. Importing data from the old phone (it had Android 8), through the settings application, did not work correctly. The old data was imported through Google and through the computer. It connects well via Bluetooth, including the Smartwatch. The localization is very fast if there is data connectivity, if not, it takes almost 3 minutes. I tested it on 5G and it works correctly. Charging the battery takes less than 1. 5 hours (20% to 100%) with the 66W charger, which is very good. On the old phone (10600 mAh) it lasted 6 hours. Very fast Wi-Fi if connected to a 5. 8GHz (802. 11ac) access point. The microphone is directional, so you have to know which side to speak from when using it on the loudspeaker (hands-free). The phone was delivered quickly and in perfect condition. Less
# 41 2023-11-07 14:43:28.161148 When I opened the package, my first thought was that 'now it is crazy'. The phone felt like a big lump in the grip. The transition from the old phone's Android 13 -> Power Armor's Android 12 went well. A couple of insignificant softwares were not installed. In use, two things shine above the others. Size and battery life. The size is just the right size to fit in the thigh pocket of the down pants. That is a small minus, Snafist is physically too big. The brutal durability of the battery is positive. No matter how you load the phone, there is 50% left in the evening. And of course wireless charging. . The package came with sceen shield - Pro Tip included - which is good to position the upper edge first. Summa summarum; when you want a phone that works as a smartphone, a hammer and a backup power source, choose this one. You will not be disappointed. My lord, my blood is big physically, but excellent otherwise. Less
# 42 2023-11-07 14:43:35.575349 The phone has been in use for about a month. The phone works well and the battery lasts about two and a half days with quite heavy internet browsing, which is a good thing. All necessary programs run well. The only thing that would be missing would be a rear camera armor glass that would protect the camera lenses. The protections of the phone seem to be sufficient and after a few drops there are no problems. I recommend it to everyone who is considering a durable phone.
# 43 2023-11-07 14:43:40.644735 You get used to the phone's large size and massive weight quite quickly. Those are actually the only things worth criticizing, you can feel the quality and durability in your fingers! The general impression is what was promised, a durable Android with a large battery. The only downsides to ease of use come from the fact that it is not easy to find racks that work for, for example, a car or bike, and universal racks or accessories are not a solution.
# 44 2023-11-07 14:43:44.978867 A robust product, with unsophisticated, simple software. A phone that you do not have to worry about getting scratched, getting wet, etc. Personally, I was excited by the microscope in the camera. It is exactly what a phone should be, especially if you do extreme sports and only.
# 45 2023-11-07 14:43:54.002120 Unbreakable phone with super battery. With normal use, it lasts up to 4 days. It is a bit heavy, but that does not bother me. So far, I have been using Armor 7 for 4 years - it fell on concrete / tiles many times and there was no trace on the screen :) For me, there is nothing better on the market than this series. Great quality and equipment at a good price.
# 46 2023-11-07 14:43:59.500464 Otherwise, a great phone and a wonderfully long-lasting battery, but the usability disappears when the applications do not work: basic messages arrive with a delay of hours, and the scaling of e. g. Snapchat is not at all right. The camera does not open and up-to-date system updates are simply not available or known. So avoid this buying mistake!
# 47 2023-11-07 14:44:04.984583 An excellent price-quality phone. No other brand offers what this phone offers. The only thing I do not like is the video stabilization, it is not ok. Everything else is ok.
# 48 2023-11-07 14:44:11.041924 An excellent phone with good features, a good price, a good processor and excellent build quality, it exceeded all my expectations, I was able to emulate PSP without any problem, the games run excellent, totally recommended.
# 49 2023-11-07 14:44:17.322148 After the update, it reboots and the only rescue for a while is to choose the option to restore factory settings. After turning off and on, some system application error and for the phone to work is . Factory reset.
# 50 2023-11-07 14:44:25.623015 Good product but worse with the delivery, the product was at the warehouse three days before delivery to the agent.
# 51 2023-11-07 14:44:30.967621 thermography works properly, I recommend
# 52 2023-11-07 14:44:33.174379 Chose to go up a model to get the FLIR
# 53 2023-11-07 14:44:40.487518 I am very satisfied with the products.
# 54 2023-11-07 14:44:47.119946 it is good cell phone, good cameras, high responding which means good processor and nice shapeI liked the screen size and I disliked fingerprint position.
# 55 2023-11-07 14:44:52.429941 My old phone was out of date and slow. My new one is much better.
# 56 2023-11-07 14:45:00.238851 It is nice and friendly user but a little Heavy to carry
# 57 2023-11-07 14:45:03.798692 Annoying google that has spread all over the system. The phone does not even automatically download numbers from the SIM card, it only attacks google and wants to connect and suck numbers from google. You have to go to settings to download contacts. Generally, at least the phone allows a lot of personalization, also managed to turn off those disgusting notifications, internet gossip appearing on the side screen supported by google. The photos are quite nice indoors, although the corners are actually out of focus. As I expected from Nokia, I can be heard well on the interlocutor.
# 58 2023-11-07 14:45:11.170185 Bought for husband. I have been using for over a year. The battery holds up well, and you know, now there are apps for almost everything. At a reasonable price we have 5g, large capacity, contactless payments. The fingerprint works very well, the system works smoothly, the phone is quite loud, you can easily listen to an audiobook while doing some work. I decided on Nokia guided by a certain sentiment and I was not disappointed, the smartphone meets all my expectations.
# 59 2023-11-07 14:45:17.817518 Good quality product, nice sound and nice display. Good workmanship. I recommend
# 60 2023-11-07 14:45:22.233720 Nokia X10 does not have a better phone. The battery is super strong.
# 61 2023-11-07 14:45:28.727816 Amazing value for money, I highly recommend this model.
# 62 2023-11-07 14:45:34.598123 Nokia always reliable. I have had several displays a bit large.
# 63 2023-11-07 14:45:40.805862 Plot as it should be. He takes super photos
# 64 2023-11-07 14:45:45.533476 as for me, Nokia Wymiata has been faithful to this brand for years
# 65 2023-11-07 14:45:52.409923 Flawless, frequent updates, 5G, affordable price
# 66 2023-11-07 14:45:59.857949 A first-class smartphone and a great price
# 67 2023-11-07 14:46:05.688801 Not chinese pure android phone :)
# 68 2023-11-07 14:46:11.367284 Super quality
# 69 2023-11-07 14:46:14.646501 Very good
# 70 2023-11-07 14:46:18.176792 I used to have an HTC and I was very happy I hope this HTC will be my friend it has good speed and is easy to use very nice look
# 71 2023-11-07 14:46:21.493077 I have been using HTC phones (Desire 500, U11 dual Sim and U11 life) for many years. Compared to the old U11 dual SIM (which unfortunately broke after a battery change), I am just as satisfied with the Desire 22 pro for my everyday use - taking phone calls with 2 SIM cards, WhatsApp, the Internet and taking photos of the children. Only the accessories have become leaner (earphones are no longer included) and the sound is a bit worse, which does not bother me since I do not listen to much music on my cell phone. The color of my YOU 11 was second to none (solar red), the golden Desire 22 pro falls off a bit. But that is not so important.
# 72 2023-11-07 14:46:27.393620 It was cheaper and there was an official trade-in campaign, so I switched from U11. Good battery life when new. It is a little vertical and feels heavy. I feel like the camera is getting harder to use. It is good that it has an earphone jack, but it is not good to have one main speaker and monaural when playing videos. Sound quality is also bad. Other than that, I was able to switch to the current situation without any discomfort. It would be nice to have a fingerprint scanner on the power button. I wonder if the HTC-likeness is decreasing. It seems that the VR headset (flow) and the set are recommended and show their true value, but the essential flow is honestly a delicate spec. The late-starting new VR goggles look good. I am personally satisfied, but I do not think it is necessary for newcomers to choose.
# 73 2023-11-07 14:46:34.745992 Coming from the 20 pro model, the new Desire 22 Pro looks good, fluid and with a good photographic sector. Battery lasts me 2 days with average use (emails/websites/whatsapp/photos and videos) *no gaming*, I tried wireless charging with 15w but it is very slow better with cable. For now updated Android 12 ver. security 1/09/2022 Build 1. 04. 2401. 2
# 74 2023-11-07 14:46:50.506903 It is at least my 6th HTC smartphone and I am a little disappointed. What made the charm of HTC ('Telephone' applications, 'Messages', etc . ) has disappeared to the detriment of Google applications which do not work at all the same. The camera is not up to par (quality and focusing leave something to be desired). Otherwise the phone is OK.
# 75 2023-11-07 14:46:54.355547 After the purchase, I had problems with making phone calls, interference, interruptions, dropping calls, inability to make a connection despite the good range indicated on the display. I decided to send the phone back, suspecting a manufacturing defect. After receiving the refund, I bought another one, the same but in a different store and again I have a problem with making calls. I used two other sim cards from different operators and the connection problem is the same. I was clearly convinced that the model has a repetitive factory defect when, talking with serious interference, I left the building and the connection quality improved immediately, without interrupting the conversation, I returned to the building and after a few steps inside, the connection quality deteriorated again. Two identical defects in two identical phones from two different stores are hardly a coincidence. Different sim cards, different operators, supposedly full range and you cannot talk. Moving the same sim card to the old dilapidated phone and there is no problem !!! Failure . Less
# 76 2023-11-07 14:47:10.002016 Is my 4th HTC phone. Previously 5 years the U11 life until the battery weakened. Are always solid quality phones with good performance. Exactly the right thing for me as a 'non-mobile phone freak' (and Apple rejecter).
# 77 2023-11-07 14:47:16.022614 I am very positively surprised that such a 'cheap' cell phone works so well! Was always a huge fan of Samsung, I now realize that prices like Samsung or Apple do not need it. I am curious how long I will enjoy it, would recommend it.
# 78 2023-11-07 14:47:22.952742 Super invincible good seller, fast delivery, good product, super shipping speed, super product quality, super CP value, super service
# 79 2023-11-07 14:47:29.780742 A Realme or Oppo for 350. 00 is definitely more fun. HTC Desire 22 Pro has nothing in common with all other Htc devices, too bad.
# 80 2023-11-07 14:47:37.562004 Excellent value for money, excellent performance of the phone which turns out to be lacking in camera performance when compared to other devices of the same range while waiting to receive the update to Android 13 already received by devices of the same and lower range
# 81 2023-11-07 14:47:41.226432 A superb product. Quality and reliability plus remarkable battery life. I am delighted
# 82 2023-11-07 14:47:44.589661 It has many advantages at this price, but it has a basic disadvantage - poor range not compensated by VoWiFi support (yes, but Polish networks do not accept it)
# 83 2023-11-07 14:47:51.882602 HTC has now returned and has always been an excellent smartphone . good price equal to others much more expensive than advertised .
# 84 2023-11-07 14:47:56.231738 The ordered product has been received, the seller delivered the goods quickly, the logistics is also very good, the customer service attitude is excellent, very patient, and gives people a sense of intimacy, I like it very much. There is also exquisite packaging, high-end atmosphere and high-grade; it can be seen that the merchant is very careful.
# 85 2023-11-07 14:48:01.922586 I am not satisfied I will complain about a refund or replacement of the camera so much money and the phone loses coverage or is completely missing updates are not done every day I hear it several times . you cannot hear you so much money for the phone and zero satisfaction.
# 86 2023-11-07 14:48:06.582350 Simple and complete
# 87 2023-11-07 14:48:11.460359 I was thinking about whether to keep it or return it, but in the end it conquered me, as it is, with pluses and minuses. You know the official presentation, I will not repeat it, these are my personal conclusions after a month of use. Strengths: - Very durable construction, feels good in the hand. Unfortunately, he slipped from the windowsill on the first floor and fell 4 meters into a cement ditch. It was chosen with 2 discrete side scratches, but it still works perfectly. Maybe I was lucky, but it was the moment when I chose to keep it, it passed the test. -Clear and bright screen, the sound of the speakers is very strong; watching movies is a real pleasure-It works smoothly, I never got stuck-The cameras deliver unexpectedly good photos in strong/medium light, rivaling much better rated phones. In low light the quality of the photos drops a lot, it is not a phone for night photos. The PRO photo mode is a joke, it has no use. Weak points: - The phone is VERY slippery (that is why it fell off the windowsill); it would really need an adherent silicone cover, but that is not available - The IR camera is a cute, useful gadget, but the photos are indicative, far from usable. - The battery is quite small and discharges quickly in some applications , could be higher. For normal use, it lasts decently for a day. To compensate, the 66w charger is really efficient, the battery charges very quickly, about 2 - 3% per minute. -Despite the advertisements, the phone is not totally waterproof. I washed it for 15 seconds under a moderate stream of water, without excesses, and the speakers were 'drowned', I could no longer talk on the phone. Fortunately, it recovered completely after a few hours, when it dried. - The side buttons are TOO accessible, the phone frequently activates in your pocket. Conclusion: If you are willing to accept its limitations and compensate for them, it is a great phone. It remains to be seen how it will behave over time. Less
# 88 2023-11-07 14:48:19.922928 A very nice phone. It is not a speed demon, but that is not the point. It lasts me over a week on a single charge. The phone is quite massive, resistant to impacts and falling from a height (which I accidentally checked myself) and heavy enough, but it still looks great. A very delicate proprietary android overlay does not bother me at all and so far I have not noticed any problems in the operation of the system. Call quality is good, volume is excellent. The screen is readable even in direct sunlight. In my opinion, a great choice for active people and for work in difficult conditions.
# 89 2023-11-07 14:48:28.819175 A very cool phone! for the first time I decided on a 'pancerniak' and it was a bull's-eye!!! The device works very well, it is very fast, it took 10 minutes to copy all the information along with all the applications from the previous phone and that is it. it is just a matter of logging in to the application. Lenses. the quality of the photos knocked me down 👍👍👍 and this price. shock!!! This is a phone that met all my expectations. The weight is also acceptable. I RECOMMEND
# 90 2023-11-07 14:48:44.204926 The phone is really great. Of the most important: Radio without the need to connect headphones (the input also has an input) Fast processor and 120hz refresh rate - you can play! Battery - use all day and you will not discharge it. There is also a practical handle (cover) with a clip - it comes in handy in construction. Really good hard phone resistant to dust and water and probably one of the few gorillaglass armored ones
# 91 2023-11-07 14:48:50.272968 Generally, I would not buy it again, the Android system without any manufacturer's overlay, such as miui in xiaomi, works just like that, the additional programmable button works only when the screen is awake, otherwise not (if you turn on the flashlight and turn off the screen, you cannot turn it off later, you have to wake up the screen). The screen unlock/lock button sometimes works sometimes not or you have to press it several times to lock the phone. A big plus for durability and recording under water and batteries, but that is about it.
# 92 2023-11-07 14:49:02.499636 Notkowizja on the plus side, but this good quality camera is not visible at all, it takes worse pictures than not one Samsung flagship or even an iPhone xr. It is comfortable to hold in hand, weighs a little less than a good power bank, as for this price it is an ordinary phone with an android overlay. The packaging and the way of packing is a great plus, it was pleasant to unpack.
# 93 2023-11-07 14:49:06.694319 Great phone. Good performance. Nice picture quality. A default: the loud sound even at minimum.
# 94 2023-11-07 14:49:12.187426 The phone looks really good with great features, for example the professional quality of the camera 106MB, RAM 8GB, ROM 258GB and the powerful MediaTek Helio G99 system chip processor and Android 12 operating system.
# 95 2023-11-07 14:49:16.999321 A solid phone in the original packaging, which also contained extras, such as a bow. The phone is quite large and heavy but fits well in the hand.
# 96 2023-11-07 14:49:22.453339 Good product.
# 97 2023-11-07 14:49:29.649624 A solid smartphone, speed sufficient for everyday use, an additional button on the housing that can soon be configured in your own way
# 98 2023-11-07 14:49:32.454693 perfect for those who need a robust mobile phone that is equally compatible with other mobile phones
# 99 2023-11-07 14:49:36.248573 The phone I was looking for is armored, resistant but looks similar to a standard smartphone
# 100 2023-11-07 14:49:42.078049 Hopefully it lasts and there are no problems. Fast delivery no customs tax. Sipplahh.
# 101 2023-11-07 14:49:48.086338 Maannnnaaapppppp Bro!!!!!!The goods arrived faster and arrived safely. The vendors are also patient with answering consumer questions. It is a shame the default TG broke, but for all that is solid, keep going, bro, I hope you will always be successful and move forward with your stall business. Thank you, bro, for the service yv is very good and satisfying🙏🙏👍👍
# 102 2023-11-07 14:49:52.029362 Super durable phone
# 103 2023-11-07 14:49:56.673814 I recommend
# 104 2023-11-07 14:50:02.209837 there is power
# 105 2023-11-07 14:50:05.804306 There is POWER!!!
# 106 2023-11-07 14:50:14.512191 Item spec according to order, fast delivery. thank you
# 107 2023-11-07 14:50:19.466622 I love the battery life, i put my phone on the charger about every third day. The ruggedness of the phone is handy. Being water proof helps so you do not have to worry about your phone falling in the water. The cons: it being a Chinese made phone, taking it to the phone repair shop for repairs is a hassle. Because they do not really know how to work on it. Another problem I have been having with the phone is if i do not use it for a couple of hours. I have to reboot the phone just to read articles or fully surf the web. Other than that i like the phone. It is definitely a good rugged device.
# 108 2023-11-07 14:50:27.347635 Super
# 109 2023-11-07 14:50:32.988378 Armored Monster! It is a pity that it does not have more stars, because it would certainly get it! From phone reviews and a pro reviews after a few shortcomings like a few words not translated from English. in the Menu, it is no exaggeration, there is nothing to pick on such nonsense! The phone is solid, holds firmly in the hand, a powerful battery, a very good camera: in the dark with a flash it takes very good pictures. I would buy it again without hesitation!
# 110 2023-11-07 14:50:39.642712 Phone 100% as expected. Big, heavy and light as a feather. The camera also takes pictures and videos very nicely, but there is no zoom here because it only reaches x2. For complete happiness, you only need to buy an elegant case. Worth the price.
# 111 2023-11-07 14:50:45.009952 Currently the hottest phone on the market. I am fully satisfied with the quality and prices.
# 112 2023-11-07 14:50:48.323027 Very prompt order. The phone is exactly as it is in the description. Very happy with the product
# 113 2023-11-07 14:50:51.903652 Prompt order, men's phone with an autonomy of up to 5 days with average use (telephony, data service, 'on' continuously, moderate use of social networks), the people from Oukitel have also worked on the camera and the pictures - they were amazed.
# 114 2023-11-07 14:50:56.438278 The best phone I have had mega battery. Just great. I recommend without hesitation. (Little big) kidney or backpack needed, but worth it anyway.
# 115 2023-11-07 14:51:02.953790 Superb! It is what I wanted! I am satisfied with the product.
# 116 2023-11-07 14:51:09.898272 recommend
# 117 2023-11-07 14:51:15.041728 I am satisfied with the product and the fact that it came very quickly.
# 118 2023-11-07 14:51:18.953427 I am very satisfied with the OUKITEL WP10, I recommend it to anyone who needs this type of phone.
# 119 2023-11-07 14:51:24.835658 Very good phone!! It is big and heavy which may be a problem for some people. No cons for me :)
# 120 2023-11-07 14:51:30.582322 Worth Its Price! The battery lasts for 8 days.
# 121 2023-11-07 14:51:34.060545 big, solid, impressive.
# 122 2023-11-07 14:51:40.190595 I recommend
# 123 2023-11-07 14:51:45.685155 Impressive by its size, its capabilities (photo, . ) and especially its battery! I absolutely do not regret my purchase . for the moment RAS I find my account - I agree . I hesitated since this brand is absolutely unknown in France / before I was at Archos
# 124 2023-11-07 14:51:50.566629 great phone except the battery which discharges quite quickly
# 125 2023-11-07 14:51:56.700532 Fast delivery, consistent with the description. Very happy
# 126 2023-11-07 14:52:01.672270 it works very well less heavy than the wp6
# 127 2023-11-07 14:52:08.854865 I decided to make myself a gift and took this smart. What can I say, the games on it just fly, on my old and close there was no such speed, I could not always play normally. The screen is cool and bright, the videos are generally great to watch, especially while I get to work or at home on a day off. And here we must pay tribute to the fact that good stereo speakers were installed. I have never noticed that he was warming himself or stupid, which is also nice. Well, fast charging is just a great cherry on the cake to all the other pluses. I strongly recommend this smartphone!
# 128 2023-11-07 14:52:13.935329 I have been using it for about a month now and it is amazing, mega-fast processor, lots of RAM plus virtual memory, so nothing cuts out and hangs here. Over time, I will probably feel the lack of built-in memory, but for now I have a lot of stock. Cons, of course, could not be missing - the camera, not to say a tragedy . is really weak, takes much worse photos than the Redmi note 7 I had, I have already tried all camera modes and options and the quality is poor, I do not know what it depends on, but the number of pixels does not match the quality of the photos taken.
# 129 2023-11-07 14:52:18.732295 At the price of 1500, there is no competition in new smartphones when it comes to performance and screen. Switching from Poco x3 pro 8/256 is a screen difference definitely a plus. There is no ghosting when scrolling and colors are more vivid. The camera is sufficient, the photos come out well, a little worse than the flagships, but there is no tragedy.
# 130 2023-11-07 14:52:23.291245 Overall, the phone is nice, but surprisingly the battery holds worse than my previous phone (POCO X3 PRO), although it has the same capacity. In addition, the fingerprint scanner is poorly solved, and taking screenshots is annoying.
# 131 2023-11-07 14:52:28.332268 I have been 4 days at the moment I like everything, fluidity, battery, screen, cameras etc etc. I liked it very much,
# 132 2023-11-07 14:52:35.254267 Purchased phone, supposedly new, but it is a 'storage deckchair' production date 07/22/2022, discharged to 0.
# 133 2023-11-07 14:52:42.045485 Very good phone I love it I hope they can also put the realme Naruto
# 134 2023-11-07 14:52:48.169542 It is easy to use and has a great camera. The very thin design
# 135 2023-11-07 14:52:51.629495 Very good processor, very responsive, great screen, very good for games.
# 136 2023-11-07 14:52:56.578140 The truth is that it is a very balanced mobile that is plenty for my private use
# 137 2023-11-07 14:53:02.595411 Very good mobile, both camera and interior, everything is going super well for now.
# 138 2023-11-07 14:53:08.168258 I bought it for price, design and performance compared to a xiaomi
# 139 2023-11-07 14:53:13.322627 Daily charging is normal but here the charging speed makes up for this minus.
# 140 2023-11-07 14:53:20.200309 Fast charging is a topic, and for such a battery size, the phone cannot be said to be heavy.
# 141 2023-11-07 14:53:26.390016 Excellent equipment and arrived before the date
# 142 2023-11-07 14:53:29.789279 phone works great performance ok for such money nice equipment.
# 143 2023-11-07 14:53:36.885824 Screen is 6. 62 and not 6. 2
# 144 2023-11-07 14:53:42.693220 Bombing device as expected
# 145 2023-11-07 14:53:47.345057 as fast as robert kubica
# 146 2023-11-07 14:53:49.673496 Whole
# 147 2023-11-07 14:53:55.300585 I recommend
# 148 2023-11-07 14:54:00.775683 It does not freeze
# 149 2023-11-07 14:54:05.429516 If, like me, you want a 'small' handset that does not resemble a portable tv, the options are pretty limited. Having flirted with the Google Pixel 6A, and finding the low screen refresh rate really obvious and detrimental to my moderate surfing needs, I instead opted for the Moto Edge 30 Neo. Great choice! Zippy usage, no lag, lovely bright screen, and I was up and running in no time. The 'professional teccie reviews' for this unit are favourable, but still grumble about the camera capabilities, but no complaints here. So far, crisp colourful shots in all shades of daylight. Way better than my old smartphone. Out of the box, you even get a plug with your charging cable (Hurrah!) and a clear plastic 'back cover' to stop your new toy getting scratched. And a big thank you to the in-store Tech team in Norwich - patient, professional and excellent service. All of which is why this happy customer wrote a review. Now if you will excuse me, I have got some photos to take.  Less
# 150 2023-11-07 14:54:11.119474 My previous phone was a monster, could not really use with one hand so I decided to go for something smaller, but had limited choices for a snapdragon, oled, wireless charging, wide-screen camera, splash proof, 120hz, dual sim phone, which were my requirements. Only thing missing was audio jack but whatever. The unit is extremely light compared to previous, transferred everything via USB, came with cable and charger, very surprised at how fast it charges, 30 mins to 100%, good accuracy with keyboard, night camera not so good, does not have built in GPS. Overall pleased even with these marginal drawbacks.
# 151 2023-11-07 14:54:20.389330 I purchased this mobile as a temporary replacement for my Xioami m11, which has developed a camera fault (no pun intended). I generally do a lot of research into any phone before i choose the one I want, almost never choosing the same make as my previous mobile. I looked at the Moto Edge 20's when they came out but the specs did not match other phones at the time but whilst looking I came across the Edge 30 models, the Edge 30 Neo stood out for me and although I have taken a slight step back in regards to screen size, camera and processor speed I am not disappointed with the phones quality, build and storage capacity, for £320 it was money well spent.
# 152 2023-11-07 14:54:26.278246 Overall happy with the phone. It is bigger than I wanted bit that seems to be the way they are all going these days. Would have been 5 stars except that the case is a little 'slippery' and difficult to stop it slipping around in (or out of) hour hand.
# 153 2023-11-07 14:54:32.272658 I bought this phone for my partner and he could not be happier great phone does everything he needs it to do. Used to have iPhone moved to Motorola needed an upgradenever looked back great phones
# 154 2023-11-07 14:54:35.019227 A great purchase. Very pleased with the product which was straight forward to set up, and is easy to use
# 155 2023-11-07 14:54:38.443259 Fantastic phone---lightweight and fast on internet---screen amazing
# 156 2023-11-07 14:54:42.649040 I received this device to test, by review. nl. The device feels lightweight and the finish is neat. I already received mine in a nice slim case so you do not have to buy it. With its size, the device fits comfortably in the hand and is not too big. Once you get started, you will notice that the device responds very quickly and everything works effortlessly. Handy features are fast and wireless charging and a number of handy hand movements that you will receive an explanation about in the so-called MOTO app: For example, you can quickly switch on your flashlight by shaking the device twice and open the camera with one hand by Turning your wrist twice, with a third turn you then switch cameras. You can also easily take a screenshot by placing 3 fingertips on the screen at the same time. The quality of the photos is disappointing compared to my expectations. it looks a bit faded and not as sharp as I expected with the high megapixels that the cameras have. All in all, a very common device with a few handy features. Less
# 157 2023-11-07 14:54:49.401094 I would not buy a second time. The size of the phone (the smallest in the financial range) and good parameters made me buy it. Unfortunately, the phone, compared to the Huawei P10, which I owned for 5 years, works very poorly. On the downside: - poor system optimization, the phone has had so many spectacular crashes that I cannot count them - the fingerprint reader is best turned off . - camera - some landscapes in good lighting - standard, but take a good quality photo for the client in room - this is not possible. As a curiosity, I will add the fact that the camera cannot take a picture of a document for an accountant. I use the phone purely for business purposes - communicators, sometimes navigation, nothing else, so I really do not understand why such weakness.
# 158 2023-11-07 14:55:04.785325 Typical Motorola, no superfluous apps, the image sequence with 144 Hz is unparalleled and the battery easily lasts three days! Once Motorola. always Motorola! Have tried all other brands and always end up with Motorola. There is no better value for money!! The new Razr will be mine again!!
# 159 2023-11-07 14:55:09.400338 Charges very quickly, also option via induction. Good screen and camera. Useful features via Motorola app. Handy size. I am satisfied with it.
# 160 2023-11-07 14:55:14.829675 The Motorola Moto edge is a nice phone that I was able to test, very handy and with many useful gadgets, such as using three fingers on the screen to take a screenshot is so handy. And rotate 2 times to take a picture.
# 161 2023-11-07 14:55:20.347184 The image on the screen has a slight tint of green. Apparently it is OLED's fault, it is worth taking this into account and reading on the internet before buying. Other than that, the rest is a plus.
# 162 2023-11-07 14:55:23.318130 Neat, one-handed operation. Fast charging, induction, clear display. Only advantages
# 163 2023-11-07 14:55:29.690334 with a 11 gb contract for 12. 99 unbelievable only to recommend, good specialist advice at Media Markt Euroindustriemarkt.
# 164 2023-11-07 14:55:34.703153 Nice mobile for the price. Feels great, is fast, charges fast, is light and not too big.
# 165 2023-11-07 14:55:45.106322 Nice phone, I did not like the display (when looking at the angle the colors were 'green')
# 166 2023-11-07 14:55:50.592278 Very happy with it. Only a slightly larger battery could have been used
# 167 2023-11-07 14:55:55.628282 After a few days of use, I am very happy with this phone. It works great, is fast and very handy.
# 168 2023-11-07 14:55:58.853724 I recommend clean android and super fast charging
# 169 2023-11-07 14:56:03.639012 Meets expectations
# 170 2023-11-07 14:56:08.431337 Excellent quality and beautiful design
# 171 2023-11-07 14:56:10.732562 I am happy
# 172 2023-11-07 14:56:14.575891 Light and handy, very fast, good sound, razor-sharp screen, photos and videos are also at a good level, so I do not know who writes these opinions that it is different. I would buy a second time
# 173 2023-11-07 14:56:21.440927 Compact size, brilliant screen, featherweight, almost pure android. That is what I wanted.
# 174 2023-11-07 14:56:26.835824 I recommend
# 175 2023-11-07 14:56:32.312806 Small and neat.
# 176 2023-11-07 14:56:38.995224 Bun.
# 177 2023-11-07 14:56:43.960593 ok
# 178 2023-11-07 14:56:49.635722 Phone delivered on time. Really solid construction: the device accidentally fell out of my pocket without any consequences. Pleasant handling and good quality screen. Like all these IPS screens, however, it is better to avoid viewing it in the sun! Reinstalled software without problem from playstore. The GPS works well and the 5000mAh battery makes it possible to space out refills. In short, I am satisfied for the moment. To be continued over time. Small problem related to Android Auto under Android 11: impossible to start waze on the car screen. We will have to wait for an update from Android Auto. By consulting the internet, it appears that this version of Android auto is quite buggy.
# 179 2023-11-07 14:57:05.023983 I regret having bought this smartphone which is anything but unbreakable. After a few small falls in the apartment, it is unusable. The seller does not want to do anything even if the guarantee is valid. I had smartphones (not unbreakable) (ex xi. ) much more robust and more efficient (and cheaper. )
# 180 2023-11-07 14:57:09.829487 The product corresponds to the advertised expectation. Despite being a robust and impact-resistant model, it did not prevent the glass from cracking the only time it fell to the ground. However, it continues to function normally.
